# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import scipy.signal as signal
import matplotlib.pyplot as plt
import librosa
from scipy.io import wavfile

# %%
sampling_rate, data = wavfile.read("guitar_grasshopper_mono.wav")

# %%
frequencies, times, my_spectrogram = signal.spectrogram(data, sampling_rate, scaling = 'spectrum', window = ('hann', ))
plt.pcolormesh(times, frequencies, np.log10(my_spectrogram))
plt.colorbar(format='%+2.0f dB')
plt.ylabel('Частота [Гц]')
plt.xlabel('Время [с]')
# Out:
# Text(0.5, 0, 'Время [с]')

# %%
import matplotlib.pyplot as plt
y, sr = librosa.load('guitar_grasshopper_mono.wav')
plt.figure(figsize=(12, 6))
D = librosa.amplitude_to_db(np.abs(librosa.stft(y)), ref = np.max)
# plt.subplot(4, 2, 2)
librosa.display.specshow(D, y_axis='log')
plt.colorbar(format='%+2.0f dB')
plt.title('Log-frequency power spectrogram')
# Out:
# Text(0.5, 1.0, 'Log-frequency power spectrogram')

# %%
D
# Out:
# array([[-80.        , -80.        , -80.        , ..., -80.        ,
#         -76.00487095, -67.23220568],
#        [-80.        , -80.        , -80.        , ..., -80.        ,
#         -77.85400046, -67.42647352],
#        [-80.        , -80.        , -80.        , ..., -80.        ,
#         -77.49210074, -67.53474218],
#        ...,
#        [-80.        , -80.        , -80.        , ..., -80.        ,
#         -80.        , -80.        ],
#        [-80.        , -80.        , -80.        , ..., -80.        ,
#         -80.        , -80.        ],
#        [-80.        , -80.        , -80.        , ..., -80.        ,
#         -80.        , -80.        ]])

# %%
import librosa

# %%
# Load the audio file
filename = "guitar_grasshopper_mono.wav"
audio, sr = librosa.load(filename, sr = None)

window_size = 1024  # Size of the window for the STFT
hop_length = int(window_size / 4)  # Hop size between consecutive windows
n_fft = window_size


spectrogram = librosa.stft(audio, n_fft=n_fft, hop_length=hop_length, window=signal.hann(window_size))
spectrogram_db = librosa.amplitude_to_db(np.abs(spectrogram), ref=np.max)

# Plot the spectrogram
plt.figure(figsize=(12, 6))
librosa.display.specshow(spectrogram_db, sr=sr, hop_length=hop_length, x_axis='time', y_axis='log') 
plt.colorbar(format='%+2.0f dB')
plt.title('Spectrogram')
plt.xlabel('Time')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
sampling_rate, data = wavfile.read("guitar_grasshopper_mono.wav")

# %%
sampling_rate
# Out:
# 44100

# %%
len(data) / sampling_rate
# Out:
# 9.5

# %%
filename = "guitar_grasshopper_mono.wav"
audio, sr = librosa.load(filename, sr=None)

# %%
np.max(audio * 2**15)
# Out:
# 32716.0

# %%
np.max(data)
# Out:
# 32716

# %%
(audio * 2**15).astype(np.int16)
# Out:
# array([  0,   0,   0, ..., 142, 311, 458], dtype=int16)

# %%
data
# Out:
# array([  0,   0,   0, ..., 142, 311, 458], dtype=int16)
